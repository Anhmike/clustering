# %% [markdown]
# # Clustering
# Below shows examples of clustering using CURE, DBSCAN, hierarchical and k-means clustering methods in kdb+/q.
#
# ### Dependencies
# To run the below notebook, the following dependencies are required.
# ```
# - embedPy
# - matplotlib
# - scikit learn
# - pyclustering (datasets used below)
#
# ```

# %% [markdown]
# ### Example 1

# %%
\l ml/ml.q
.ml.loadfile`:clust/init.q
\l graphics.q
plt:.p.import`matplotlib.pyplot
.p.import[`mpl_toolkits.mplot3d]`:Axes3D;
fcps:.p.import[`pyclustering.samples.definitions]`:FCPS_SAMPLES
read:.p.import[`pyclustering.utils]`:read_sample

# %%
d1:(60#"F";",")0:`:data/ss5.csv
plt[`:scatter][;]. flip d1;
plt[`:show][];

# %%
/cure w/ e2dist (q and q with C) and mdist (q only)
plot[`cure;d1;-1_(cross/)(4;`e2dist`mdist;5;0;01b;0b)]

# %%
/dbscan using e2dist
plot[`dbscan;d1;5 5]

# %%
/hierarchical - `single`complete`average`centroid w/ e2dist,edist and mdist
plot[`hc;d1;(cross/)(4;-1_key .ml.clust.kd.i.dd;-1_key .ml.clust.kd.i.ld)]

# %%
/hierarchical - ward only w/ e2dist
plot[`ward;d1;(4;`e2dist;`ward)]

# %%
/k-means
plot[`kmeans;d1;(cross/)(4;1000;1b;`e2dist`mdist`cshev)]

# %% [markdown]
# ### Example 2

# %%
d2:flip@[;`Income`SpendingScore]("SSFFF";(),",")0:`:data/cust.csv
plt[`:scatter][;]. flip d2;
plt[`:show][];

# %%
/cure
plot[`cure;d2;-1_(cross/)(4;`e2dist`mdist;5;0;01b;0b)]

# %%
/dbscan
plot[`dbscan;d2;3 100]

# %%
/hierarchical - `single`complete`average`centroid
plot[`hc;d2;(cross/)(5;-1_key .ml.clust.kd.i.dd;-1_key .ml.clust.kd.i.ld)]

# %%
/hierarchical - ward
plot[`ward;d2;(5;`e2dist;`ward)]

# %%
/k-means
plot[`kmeans;d2;(cross/)(5;20;1b;`e2dist`mdist`cshev)]

# %% [markdown]
# ### Example 3

# %%
dsc:{[n;r;s](r+n?s-r)*/:(cos;sin)@\:4*n?acos 0}
d3 :flip(-5 1)+(1 1.5)*dsc[1000;0;1.8],'dsc[2000;3.1;4.2],'dsc[4000;5.2;6.5]
d3,:flip(4 -1)+(1 8)*dsc[4000;0;1.]
d3@:neg[1000&count d3]?count d3
plt[`:scatter][;]. flip d3;
plt[`:show][];

# %%
/cure
plot[`cure;d3;-1_(cross/)(4;`e2dist`mdist;30;0;01b;0b)]

# %%
/dbscan
plot[`dbscan;d3;2 1.2];

# %%
/hierarchical - `single`complete`average`centroid
plot[`hc;d3;(cross/)(4;-1_key .ml.clust.kd.i.dd;-1_key .ml.clust.kd.i.ld)]

# %%
/hierarchical - ward
plot[`ward;d3;(4;`e2dist;`ward)]

# %%
/k-means
plot[`kmeans;d3;(cross/)(4;70;0b;`e2dist`mdist`cshev)]

# %% [markdown]
# ### Example 4 - 3D

# %%
d4:read[fcps`:SAMPLE_CHAINLINK]`
fig:plt[`:figure][];
ax:fig[`:add_subplot][111;`projection pykw"3d"];
ax[`:scatter]. flip d4;
plt[`:show][];

# %%
/cure
plot[`cure;d4;-1_(cross/)(2;`e2dist`mdist;30;0;01b;0b)];

# %%
/dbscan
plot[`dbscan;d4;20 .1]

# %%
/hierarchical - `single`complete`average`centroid
plot[`hc;d4;(cross/)(2;-1_key .ml.clust.kd.i.dd;-1_key .ml.clust.kd.i.ld)]

# %%
/hierarchical - `ward
plot[`ward;d4;(2;`e2dist;`ward)]

# %%
/k-means
plot[`kmeans;d4;(cross/)(2;10;1b;`e2dist`mdist`cshev)]

# %% [markdown]
# ---
